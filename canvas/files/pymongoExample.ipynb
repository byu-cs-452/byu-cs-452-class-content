# %%
#!/usr/bin/python

from pymongo import MongoClient, DESCENDING

client = MongoClient("mongodb+srv://snell:MongoPassword2023@cluster0.8dvuw4m.mongodb.net/?retryWrites=true&w=majority")

# %%
db = client.Zips

provozips = db.zipcodes.find({'city': 'PROVO'}, {'city':1, 'state':1, 'pop':1}).sort('pop', DESCENDING)

for zip in provozips:
    print(zip)
# Out:
# {'_id': '84604', 'city': 'PROVO', 'pop': 43841, 'state': 'UT'}
# {'_id': '84606', 'city': 'PROVO', 'pop': 23536, 'state': 'UT'}
# {'_id': '84601', 'city': 'PROVO', 'pop': 20121, 'state': 'UT'}
# {'_id': '57774', 'city': 'PROVO', 'pop': 32, 'state': 'SD'}

# %%
    
agr = [
{ '$group': { '_id': "$state", 'totalPop': { '$sum': "$pop" } } },
{ '$match': { 'totalPop': { '$gte': 5 * 1000 * 1000 } } }
] 

val = list(db.zipcodes.aggregate(agr))

print("%10s  | %13s" % ('State', 'Population'))
print("    ========|===============")
for v in val:
    print("%10s %15s" %(v['_id'], v['totalPop']))
# Out:
#      State  |    Population
#     ========|===============
#         IN         5544136
#         GA         6478216
#         NC         6628637
#         OH        10846517
#         IL        11427576
#         MI         9295297
#         TX        16984601
#         MA         6016425
#         CA        29754890
#         VA         6181479
#         PA        11881643
#         MO         5110648
#         FL        12686644
#         NJ         7730188
#         NY        17990402
